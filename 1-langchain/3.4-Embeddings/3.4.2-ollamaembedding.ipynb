# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
embeddings=(
    OllamaEmbeddings(model="gemma:2b") #by default it uses llama2
)

# %%
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1=embeddings.embed_documents(
    [
        "alpha is the first letter in the Greek alphabet",
        "beta is second letter in the Greek alphabet",
    ]
)

# %%
r1
# Out:
# [[-0.6116859912872314,
#   0.12653161585330963,
#   -0.00887338537722826,
#   1.3109265565872192,
#   2.0701889991760254,
#   0.28523221611976624,
#   -0.047473590821027756,
#   0.5012632012367249,
#   0.5835610032081604,
#   -1.1110680103302002,
#   0.0644959956407547,
#   0.7313810586929321,
#   -0.5912426114082336,
#   0.5904275178909302,
#   -1.929693341255188,
#   -0.593269407749176,
#   1.5703215599060059,
#   -0.8712446689605713,
#   0.449272483587265,
#   0.20559559762477875,
#   0.5053544044494629,
#   0.4158632457256317,
#   -3.0197160243988037,
#   -0.9676629900932312,
#   -2.2456934452056885,
#   0.3672485053539276,
#   -0.38674992322921753,
#   0.28526055812835693,
#   2.2630228996276855,
#   0.4662434458732605,
#   1.0931717157363892,
#   -0.23565120995044708,
#   0.8905699253082275,
#   0.1770445853471756,
#   -0.36382171511650085,
#   0.5936030149459839,
#   0.8004812002182007,
#   -0.4127067029476166,
#   0.7895891666412354,
#   -0.5612772107124329,
# ...

# %%
embeddings.aembed_query("what is first letter of greek alphabet?")
# Out:
# <coroutine object Embeddings.aembed_query at 0x000002964A7C27A0>

# %%
# other models can be used as well
embeddings=OllamaEmbeddings(model="mxbai-embed-large")
text="meow  meow meow cat"
query=embeddings.embed_query(text)
query
# Out:
# [0.22620822489261627,
#  0.4183245599269867,
#  -0.4249506890773773,
#  0.050948984920978546,
#  -0.18013030290603638,
#  -0.6916881203651428,
#  -0.7087120413780212,
#  0.5249881744384766,
#  0.30761662125587463,
#  0.5142857432365417,
#  0.2769469618797302,
#  0.8558846116065979,
#  -0.6603312492370605,
#  0.2091214507818222,
#  -0.849379301071167,
#  -0.4632970988750458,
#  0.02777833864092827,
#  -0.315714955329895,
#  -0.14869415760040283,
#  0.1823893040418625,
#  0.24534176290035248,
#  0.42662906646728516,
#  -1.5270721912384033,
#  -0.016956061124801636,
#  -0.23793211579322815,
#  0.6446014046669006,
#  -0.29601386189460754,
#  -0.19290080666542053,
#  1.0296143293380737,
#  0.5362108945846558,
#  -0.024386834353208542,
#  -0.704123318195343,
#  0.30027714371681213,
#  -1.1295661926269531,
#  0.06284669041633606,
#  -0.8855990171432495,
#  0.6362192630767822,
#  0.2309264838695526,
#  0.21774812042713165,
#  -0.835465133190155,
#  0.29559817910194397,
# ...

# %%
len(query)
# Out:
# 1024
